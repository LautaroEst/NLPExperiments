# %%
import pandas as pd

# %% [markdown]
# 'hitid session task believes_is_better_than_partner_A_yes believes_is_better_than_partner_A_no believes_is_better_than_partner_B_yes believes_is_better_than_partner_B_no bored_with_game_A_yes bored_with_game_A_no bored_with_game_B_yes bored_with_game_B_no difficult_for_partner_to_speak_A_yes difficult_for_partner_to_speak_A_no difficult_for_partner_to_speak_B_yes difficult_for_partner_to_speak_B_no directs_the_conversation_A_yes directs_the_conversation_A_no directs_the_conversation_B_yes directs_the_conversation_B_no contributes_to_successful_completion_A_yes contributes_to_successful_completion_A_no contributes_to_successful_completion_B_yes contributes_to_successful_completion_B_no frustrated_with_partner_A_yes frustrated_with_partner_A_no frustrated_with_partner_B_yes frustrated_with_partner_B_no frustrated_with_game_A_yes frustrated_with_game_A_no frustrated_with_game_B_yes frustrated_with_game_B_no engaged_in_game_A_yes engaged_in_game_A_no engaged_in_game_B_yes engaged_in_game_B_no gives_encouragement_A_yes gives_encouragement_A_no gives_encouragement_B_yes gives_encouragement_B_no making_self_clear_A_yes making_self_clear_A_no making_self_clear_B_yes making_self_clear_B_no planning_what_to_say_A_yes planning_what_to_say_A_no planning_what_to_say_B_yes planning_what_to_say_B_no polite_A_yes polite_A_no polite_B_yes polite_B_no dislikes_partner_A_yes dislikes_partner_A_no dislikes_partner_B_yes dislikes_partner_B_no trying_to_be_liked_A_yes trying_to_be_liked_A_no trying_to_be_liked_B_yes trying_to_be_liked_B_no trying_to_dominate_A_yes trying_to_dominate_A_no trying_to_dominate_B_yes trying_to_dominate_B_no conversation_awkward_yes conversation_awkward_no flow_naturally_yes flow_naturally_no hard_time_understanding_each_other_yes hard_time_understanding_each_other_no like_more_A like_more_B rather_have_as_a_partner_A rather_have_as_a_partner_B directing_the_conversation_A directing_the_conversation_B dominates_the_conversation_A dominates_the_conversation_B likes_the_other_person_more_A likes_the_other_person_more_B acting_superior_A acting_superior_B more_polite_A more_polite_B more_frustrated_A more_frustrated_B'

# %%
df = pd.read_csv("../../data/games_uba/social-variables.csv").loc[:,
    ["hitid","trying_to_be_liked_A_yes","trying_to_be_liked_B_yes","trying_to_be_liked_A_no","trying_to_be_liked_B_no"]
].set_index("hitid")
df[df < 4] = 0
df[df >= 4] = 1
df
# df.loc[:,["trying_to_be_liked_A_yes","trying_to_be_liked_A_no"]].sum(axis=1)
# Out:
#         trying_to_be_liked_A_yes  trying_to_be_liked_B_yes  \
# hitid
# g10t1                          0                         1
# g10t10                         0                         1
# g10t11                         0                         1
# g10t12                         0                         0
# g10t13                         0                         0
# ...                          ...                       ...
# g9t5                           0                         0
# g9t6                           1                         0
# g9t7                           0                         1
# g9t8                           0                         0
# g9t9                           1                         0
#
#         trying_to_be_liked_A_no  trying_to_be_liked_B_no
# hitid
# g10t1                         0                        0
# g10t10                        1                        0
# g10t11                        0                        0
# ...
